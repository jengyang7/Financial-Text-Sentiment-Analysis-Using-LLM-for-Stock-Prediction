# %%
# Historical News Headlines Collector for Top 20 US Stocks - MONTHLY PREMIUM VERSION
# Using Polygon.io PREMIUM API to collect 5 years of news data (2020-01-01 to 2025-01-01)
# Premium features: No rate limits, up to 1000 articles per request, news ranking

import requests
import pandas as pd
import time
from datetime import datetime, timedelta
import os
import json
from typing import List, Dict, Any
import logging
import numpy as np
from calendar import monthrange

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# Polygon.io API configuration - PREMIUM ACCOUNT
POLYGON_API_KEY = "rXpcpeYvCUXaKrW2knMKeh6XGgsksIrs"  # Premium API key
BASE_URL = "https://api.polygon.io"

# Top 20 US stocks by market cap (as of 2024)
TOP_20_STOCKS = [
    "MSFT", "NVDA", "AAPL", "AMZN", "GOOG", "META", "AVGO", "BRK.B", 
    "TSLA", "JPM", "WMT", "LLY", "V", "ORCL", "NFLX", "MA", 
    "XOM", "COST", "PG", "JNJ"
]

# Date range - 5 years of data
START_DATE = "2020-06-20"
END_DATE = "2025-06-20"

print("PREMIUM Monthly Historical News Collector Initialized")
print(f"Date Range: {START_DATE} to {END_DATE} (5 years)")
print(f"Stocks: {len(TOP_20_STOCKS)} companies")
print(f"Target: All headlines per month per stock (up to 1000 per request)")
print(f"Premium API: No rate limits, unlimited requests")
# Out:
# PREMIUM Monthly Historical News Collector Initialized
# Date Range: 2020-06-20 to 2025-06-20 (5 years)
# Stocks: 20 companies
# Target: All headlines per month per stock (up to 1000 per request)
# Premium API: No rate limits, unlimited requests

# %%
def get_news_for_stock_month(ticker: str, month_start_date: str, month_end_date: str, limit: int = 1000) -> List[Dict[str, Any]]:
    """
    Fetch news headlines for a specific stock over a full month.
    Note: The Polygon API has a max limit of 1000 results per request.
    For a more robust solution on popular stocks, pagination would be required.
    
    Args:
        ticker: Stock symbol (e.g., 'AAPL')
        month_start_date: The first day of the month in YYYY-MM-DD format
        month_end_date: The last day of the month in YYYY-MM-DD format
        limit: Number of headlines to fetch (max 1000 for Polygon API)
    
    Returns:
        List of news articles
    """
    url = f"{BASE_URL}/v2/reference/news"
    
    params = {
        'ticker': ticker,
        'published_utc.gte': month_start_date,
        'published_utc.lte': month_end_date,  # Use lte for the last day of the month
        'limit': limit,  # Increased limit for a full month
        'order': 'desc',
        'sort': 'published_utc',
        'apikey': POLYGON_API_KEY
    }
    
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        
        if data['status'] == 'OK' and 'results' in data:
            return data['results']
        else:
            logger.warning(f"No news found for {ticker} in month {month_start_date[:7]}")
            return []
            
    except requests.exceptions.RequestException as e:
        logger.error(f"Error fetching news for {ticker} in month {month_start_date[:7]}: {e}")
        return []
    except json.JSONDecodeError as e:
        logger.error(f"Error parsing JSON for {ticker} in month {month_start_date[:7]}: {e}")
        return []

def process_news_article(article: Dict[str, Any], ticker: str) -> Dict[str, Any]:
    """
    Process and clean a news article
    """
    # Extract the actual publication date from the API response
    published_utc = article.get('published_utc', '')
    
    # Convert to date format (M/D/YYYY) if datetime string is provided
    if published_utc:
        try:
            # Parse the ISO format datetime and convert to M/D/YYYY format
            dt = datetime.fromisoformat(published_utc.replace('Z', '+00:00'))
            date = f"{dt.month}/{dt.day}/{dt.year}"
        except Exception as e:
            # Fallback to original published_utc if parsing fails
            date = published_utc
    else:
        date = ''
    
    return {
        'ticker': ticker,
        'date': date,  # Use actual publication date in M/D/YYYY format
        'title': article.get('title', ''),
        'description': article.get('description', ''),
        'author': article.get('author', ''),
        'published_utc': published_utc,
        'article_url': article.get('article_url', ''),
        'publisher_name': article.get('publisher', {}).get('name', ''),
        'publisher_homepage_url': article.get('publisher', {}).get('homepage_url', ''),
        'tickers': ','.join(article.get('tickers', [])),
        'keywords': ','.join(article.get('keywords', []))
    }

print("News fetching functions (monthly) defined")
# Out:
# News fetching functions (monthly) defined

# %%
def generate_monthly_ranges(start_date: str, end_date: str) -> List[Dict[str, str]]:
    """
    Generate a list of start and end dates for each month in the range.
    """
    start = datetime.strptime(start_date, '%Y-%m-%d')
    end = datetime.strptime(end_date, '%Y-%m-%d')
    
    monthly_ranges = []
    current_date = start
    
    while current_date < end:
        month_start = current_date.replace(day=1)
        days_in_month = monthrange(current_date.year, current_date.month)[1]
        month_end = current_date.replace(day=days_in_month)
        
        monthly_ranges.append({
            'start': month_start.strftime('%Y-%m-%d'),
            'end': month_end.strftime('%Y-%m-%d')
        })
        
        current_date = month_end + timedelta(days=1)
    
    return monthly_ranges

# Removed save_progress function as requested

# Generate the monthly date ranges
monthly_ranges = generate_monthly_ranges(START_DATE, END_DATE)
total_months = len(monthly_ranges)
total_requests = total_months * len(TOP_20_STOCKS)

print(f"Generated {total_months} months to process (5 years)")
print(f"Total API requests to be made: {total_requests:,}")
print(f"Estimated time with premium API (0.2s delay): {total_requests * 0.2 / 60:.1f} minutes")
print("Utility functions (monthly) defined")
# Out:
# Generated 61 months to process (5 years)
# Total API requests to be made: 1,220
# Estimated time with premium API (0.2s delay): 4.1 minutes
# Utility functions (monthly) defined

# %%
# Main data collection function - MONTHLY PREMIUM VERSION
def collect_historical_news_monthly(rate_limit_delay: float = 0.2) -> List[Dict[str, Any]]:
    """
    Collect historical news data for all stocks, iterating by month.
    
    Args:
        rate_limit_delay: Delay between API calls to be safe.
    
    Returns:
        List of all collected news articles, sorted by ticker then by date.
    """
    all_news_data = []
    
    monthly_ranges = generate_monthly_ranges(START_DATE, END_DATE)
    total_combinations = len(TOP_20_STOCKS) * len(monthly_ranges)
    current_count = 0
    
    logger.info(f"Starting monthly data collection...")
    logger.info(f"Total combinations (Stock x Month): {total_combinations}")
    
    for month_range in monthly_ranges:
        month_start = month_range['start']
        month_end = month_range['end']
        
        for ticker in TOP_20_STOCKS:
            current_count += 1
            
            logger.info(f"Progress: {current_count}/{total_combinations} - Fetching {ticker} news for month {month_start[:7]}")
            
            # Fetch news for this ticker and month
            news_articles = get_news_for_stock_month(ticker, month_start, month_end, limit=1000)
            
            # Process each article
            for article in news_articles:
                processed_article = process_news_article(article, ticker)  # Use actual published date
                all_news_data.append(processed_article)
            
            logger.info(f"Found {len(news_articles)} articles for {ticker} in month {month_start[:7]}")
            
            # Minimal delay
            if rate_limit_delay > 0:
                time.sleep(rate_limit_delay)
    
    # Sort by ticker, then by date
    all_news_data.sort(key=lambda x: (x['ticker'], x['date']))
    
    # Final save
    df = pd.DataFrame(all_news_data)
    df.to_csv("historical_news_monthly_final.csv", index=False)
    logger.info(f"Data collection completed! Total articles: {len(all_news_data)}")
    logger.info(f"Data sorted by ticker, then by date and saved to: historical_news_monthly_final.csv")
    
    return all_news_data

print("Main monthly collection function defined")
print("Ready to start data collection")
# Out:
# Main monthly collection function defined
# Ready to start data collection

# %% [markdown]
# ## 🚀 Instructions for Monthly Collection
#
# This notebook is configured to fetch data **monthly** instead of daily. This significantly reduces the number of API calls and speeds up the collection process.
#
# 1.  **API Key**: Ensure your Premium Polygon.io API key is set in the first cell.
# 2.  **Collection Method**: The script now iterates through each month from the `START_DATE` to the `END_DATE`.
# 3.  **API Limit**: For each month, it attempts to fetch up to **1000 articles**. Note that this is a limitation of a single API request. For highly active stocks, a month could have more than 1000 articles, and a more advanced script would need to handle pagination to retrieve all of them.
# 4.  **Efficiency**: This method is much faster and more efficient for collecting large historical datasets.
# 5.  **Output File**: The final data will be saved to `historical_news_monthly_final.csv`.
#
# **Run the next cell to start the MONTHLY data collection process!**

# %%
# 🚀 START MONTHLY DATA COLLECTION
# Make sure you've set your API key in the first cell before running this!

# Verify API key is set
if 'YOUR_POLYGON_API_KEY' in POLYGON_API_KEY:
    print("ERROR: Please set your Polygon.io API key in the first cell!")
else:
    print("API key is set.")
    
    # Test API connection with a single monthly request
    print("Testing API connection with a monthly request...")
    test_news = get_news_for_stock_month("AAPL", "2024-05-01", "2024-05-31", limit=5)
    
    if test_news is not None:
        print(f"API test successful! Found {len(test_news)} article(s) for the month.")
        print("Starting full monthly data collection...")
        
        # Start the monthly data collection
        all_collected_news = collect_historical_news_monthly(
            rate_limit_delay=0.2
        )
        
        print(f"\nCollection completed!")
        print(f"Total articles collected: {len(all_collected_news)}")
        print(f"Data saved to: historical_news_monthly_final.csv")
        
    else:
        print("API test failed. Please check your API key, internet connection, and account status.")
# Out:
# API key is set.
# Testing API connection with a monthly request...
# 2025-06-20 18:07:39,037 - INFO - Starting monthly data collection...
# 2025-06-20 18:07:39,037 - INFO - Total combinations (Stock x Month): 1220
# 2025-06-20 18:07:39,037 - INFO - Progress: 1/1220 - Fetching MSFT news for month 2020-06
# API test successful! Found 5 article(s) for the month.
# Starting full monthly data collection...
# 2025-06-20 18:07:39,831 - INFO - Found 2 articles for MSFT in month 2020-06
# 2025-06-20 18:07:40,033 - INFO - Progress: 2/1220 - Fetching NVDA news for month 2020-06
# 2025-06-20 18:07:40,768 - INFO - Found 0 articles for NVDA in month 2020-06
# 2025-06-20 18:07:40,969 - INFO - Progress: 3/1220 - Fetching AAPL news for month 2020-06
# 2025-06-20 18:07:41,691 - INFO - Found 6 articles for AAPL in month 2020-06
# 2025-06-20 18:07:41,893 - INFO - Progress: 4/1220 - Fetching AMZN news for month 2020-06
# 2025-06-20 18:07:42,615 - INFO - Found 3 articles for AMZN in month 2020-06
# 2025-06-20 18:07:42,817 - INFO - Progress: 5/1220 - Fetching GOOG news for month 2020-06
# 2025-06-20 18:07:43,591 - INFO - Found 1 articles for GOOG in month 2020-06
# 2025-06-20 18:07:43,793 - INFO - Progress: 6/1220 - Fetching META news for month 2020-06
# 2025-06-20 18:07:44,583 - INFO - Found 0 articles for META in month 2020-06
# 2025-06-20 18:07:44,785 - INFO - Progress: 7/1220 - Fetching AVGO news for month 2020-06
# 2025-06-20 18:07:45,517 - INFO - Found 0 articles for AVGO in month 2020-06
# 2025-06-20 18:07:45,718 - INFO - Progress: 8/1220 - Fetching BRK.B news for month 2020-06
# 2025-06-20 18:07:46,460 - INFO - Found 0 articles for BRK.B in month 2020-06
# 2025-06-20 18:07:46,662 - INFO - Progress: 9/1220 - Fetching TSLA news for month 2020-06
# 2025-06-20 18:07:47,437 - INFO - Found 1 articles for TSLA in month 2020-06
# 2025-06-20 18:07:47,638 - INFO - Progress: 10/1220 - Fetching JPM news for month 2020-06
# 2025-06-20 18:07:48,424 - INFO - Found 2 articles for JPM in month 2020-06
# 2025-06-20 18:07:48,625 - INFO - Progress: 11/1220 - Fetching WMT news for month 2020-06
# 2025-06-20 18:07:49,372 - INFO - Found 0 articles for WMT in month 2020-06
# 2025-06-20 18:07:49,573 - INFO - Progress: 12/1220 - Fetching LLY news for month 2020-06
# 2025-06-20 18:07:50,335 - INFO - Found 1 articles for LLY in month 2020-06
# 2025-06-20 18:07:50,536 - INFO - Progress: 13/1220 - Fetching V news for month 2020-06
# 2025-06-20 18:07:51,297 - INFO - Found 0 articles for V in month 2020-06
# 2025-06-20 18:07:51,498 - INFO - Progress: 14/1220 - Fetching ORCL news for month 2020-06
# 2025-06-20 18:07:52,239 - INFO - Found 0 articles for ORCL in month 2020-06
# 2025-06-20 18:07:52,440 - INFO - Progress: 15/1220 - Fetching NFLX news for month 2020-06
# 2025-06-20 18:07:53,186 - INFO - Found 2 articles for NFLX in month 2020-06
# 2025-06-20 18:07:53,388 - INFO - Progress: 16/1220 - Fetching MA news for month 2020-06
# 2025-06-20 18:07:54,139 - INFO - Found 0 articles for MA in month 2020-06
# 2025-06-20 18:07:54,339 - INFO - Progress: 17/1220 - Fetching XOM news for month 2020-06
# 2025-06-20 18:07:55,103 - INFO - Found 1 articles for XOM in month 2020-06
# 2025-06-20 18:07:55,304 - INFO - Progress: 18/1220 - Fetching COST news for month 2020-06
# 2025-06-20 18:07:56,067 - INFO - Found 0 articles for COST in month 2020-06
# 2025-06-20 18:07:56,269 - INFO - Progress: 19/1220 - Fetching PG news for month 2020-06
# 2025-06-20 18:07:57,012 - INFO - Found 0 articles for PG in month 2020-06
# 2025-06-20 18:07:57,212 - INFO - Progress: 20/1220 - Fetching JNJ news for month 2020-06
# 2025-06-20 18:07:57,976 - INFO - Found 0 articles for JNJ in month 2020-06
# 2025-06-20 18:07:58,178 - INFO - Progress: 21/1220 - Fetching MSFT news for month 2020-07
# 2025-06-20 18:07:58,959 - INFO - Found 5 articles for MSFT in month 2020-07
# 2025-06-20 18:07:59,161 - INFO - Progress: 22/1220 - Fetching NVDA news for month 2020-07
# 2025-06-20 18:07:59,937 - INFO - Found 0 articles for NVDA in month 2020-07
# 2025-06-20 18:08:00,139 - INFO - Progress: 23/1220 - Fetching AAPL news for month 2020-07
# 2025-06-20 18:08:00,907 - INFO - Found 7 articles for AAPL in month 2020-07
# 2025-06-20 18:08:01,108 - INFO - Progress: 24/1220 - Fetching AMZN news for month 2020-07
# 2025-06-20 18:08:01,872 - INFO - Found 8 articles for AMZN in month 2020-07
# 2025-06-20 18:08:02,073 - INFO - Progress: 25/1220 - Fetching GOOG news for month 2020-07
# 2025-06-20 18:08:02,884 - INFO - Found 5 articles for GOOG in month 2020-07
# 2025-06-20 18:08:03,086 - INFO - Progress: 26/1220 - Fetching META news for month 2020-07
# 2025-06-20 18:08:03,854 - INFO - Found 0 articles for META in month 2020-07
# 2025-06-20 18:08:04,055 - INFO - Progress: 27/1220 - Fetching AVGO news for month 2020-07
# 2025-06-20 18:08:04,795 - INFO - Found 0 articles for AVGO in month 2020-07
# 2025-06-20 18:08:04,997 - INFO - Progress: 28/1220 - Fetching BRK.B news for month 2020-07
# 2025-06-20 18:08:05,774 - INFO - Found 0 articles for BRK.B in month 2020-07
# 2025-06-20 18:08:05,975 - INFO - Progress: 29/1220 - Fetching TSLA news for month 2020-07
# 2025-06-20 18:08:06,746 - INFO - Found 6 articles for TSLA in month 2020-07
# 2025-06-20 18:08:06,947 - INFO - Progress: 30/1220 - Fetching JPM news for month 2020-07
# 2025-06-20 18:08:07,689 - INFO - Found 2 articles for JPM in month 2020-07
# 2025-06-20 18:08:07,890 - INFO - Progress: 31/1220 - Fetching WMT news for month 2020-07
# 2025-06-20 18:08:08,653 - INFO - Found 0 articles for WMT in month 2020-07
# 2025-06-20 18:08:08,855 - INFO - Progress: 32/1220 - Fetching LLY news for month 2020-07
# 2025-06-20 18:08:09,598 - INFO - Found 0 articles for LLY in month 2020-07
# 2025-06-20 18:08:09,799 - INFO - Progress: 33/1220 - Fetching V news for month 2020-07
# 2025-06-20 18:08:10,595 - INFO - Found 0 articles for V in month 2020-07
# 2025-06-20 18:08:10,797 - INFO - Progress: 34/1220 - Fetching ORCL news for month 2020-07
# 2025-06-20 18:08:11,627 - INFO - Found 0 articles for ORCL in month 2020-07
# 2025-06-20 18:08:11,828 - INFO - Progress: 35/1220 - Fetching NFLX news for month 2020-07
# 2025-06-20 18:08:12,564 - INFO - Found 11 articles for NFLX in month 2020-07
# 2025-06-20 18:08:12,765 - INFO - Progress: 36/1220 - Fetching MA news for month 2020-07
# 2025-06-20 18:08:13,517 - INFO - Found 0 articles for MA in month 2020-07
# 2025-06-20 18:08:13,718 - INFO - Progress: 37/1220 - Fetching XOM news for month 2020-07
# 2025-06-20 18:08:14,438 - INFO - Found 1 articles for XOM in month 2020-07
# 2025-06-20 18:08:14,640 - INFO - Progress: 38/1220 - Fetching COST news for month 2020-07
# 2025-06-20 18:08:15,393 - INFO - Found 0 articles for COST in month 2020-07
# 2025-06-20 18:08:15,594 - INFO - Progress: 39/1220 - Fetching PG news for month 2020-07
# 2025-06-20 18:08:16,323 - INFO - Found 0 articles for PG in month 2020-07
# 2025-06-20 18:08:16,524 - INFO - Progress: 40/1220 - Fetching JNJ news for month 2020-07
# 2025-06-20 18:08:17,257 - INFO - Found 0 articles for JNJ in month 2020-07
# 2025-06-20 18:08:17,459 - INFO - Progress: 41/1220 - Fetching MSFT news for month 2020-08
# 2025-06-20 18:08:18,200 - INFO - Found 3 articles for MSFT in month 2020-08
# 2025-06-20 18:08:18,402 - INFO - Progress: 42/1220 - Fetching NVDA news for month 2020-08
# 2025-06-20 18:08:19,194 - INFO - Found 4 articles for NVDA in month 2020-08
# 2025-06-20 18:08:19,394 - INFO - Progress: 43/1220 - Fetching AAPL news for month 2020-08
# 2025-06-20 18:08:20,160 - INFO - Found 12 articles for AAPL in month 2020-08
# 2025-06-20 18:08:20,361 - INFO - Progress: 44/1220 - Fetching AMZN news for month 2020-08
# 2025-06-20 18:08:21,146 - INFO - Found 8 articles for AMZN in month 2020-08
# 2025-06-20 18:08:21,348 - INFO - Progress: 45/1220 - Fetching GOOG news for month 2020-08
# 2025-06-20 18:08:22,122 - INFO - Found 7 articles for GOOG in month 2020-08
# 2025-06-20 18:08:22,323 - INFO - Progress: 46/1220 - Fetching META news for month 2020-08
# 2025-06-20 18:08:23,076 - INFO - Found 0 articles for META in month 2020-08
# 2025-06-20 18:08:23,278 - INFO - Progress: 47/1220 - Fetching AVGO news for month 2020-08
# 2025-06-20 18:08:24,002 - INFO - Found 0 articles for AVGO in month 2020-08
# 2025-06-20 18:08:24,204 - INFO - Progress: 48/1220 - Fetching BRK.B news for month 2020-08
# 2025-06-20 18:08:24,958 - INFO - Found 0 articles for BRK.B in month 2020-08
# 2025-06-20 18:08:25,159 - INFO - Progress: 49/1220 - Fetching TSLA news for month 2020-08
# 2025-06-20 18:08:25,942 - INFO - Found 3 articles for TSLA in month 2020-08
# 2025-06-20 18:08:26,143 - INFO - Progress: 50/1220 - Fetching JPM news for month 2020-08
# 2025-06-20 18:08:26,918 - INFO - Found 0 articles for JPM in month 2020-08
# 2025-06-20 18:08:27,119 - INFO - Progress: 51/1220 - Fetching WMT news for month 2020-08
# 2025-06-20 18:08:27,910 - INFO - Found 3 articles for WMT in month 2020-08
# 2025-06-20 18:08:28,111 - INFO - Progress: 52/1220 - Fetching LLY news for month 2020-08
# 2025-06-20 18:08:28,866 - INFO - Found 0 articles for LLY in month 2020-08
# 2025-06-20 18:08:29,068 - INFO - Progress: 53/1220 - Fetching V news for month 2020-08
# 2025-06-20 18:08:29,833 - INFO - Found 0 articles for V in month 2020-08
# 2025-06-20 18:08:30,034 - INFO - Progress: 54/1220 - Fetching ORCL news for month 2020-08
# 2025-06-20 18:08:30,766 - INFO - Found 0 articles for ORCL in month 2020-08
# 2025-06-20 18:08:30,967 - INFO - Progress: 55/1220 - Fetching NFLX news for month 2020-08
# 2025-06-20 18:08:31,719 - INFO - Found 9 articles for NFLX in month 2020-08
# 2025-06-20 18:08:31,920 - INFO - Progress: 56/1220 - Fetching MA news for month 2020-08
# 2025-06-20 18:08:32,682 - INFO - Found 0 articles for MA in month 2020-08
# 2025-06-20 18:08:32,883 - INFO - Progress: 57/1220 - Fetching XOM news for month 2020-08
# 2025-06-20 18:08:33,651 - INFO - Found 1 articles for XOM in month 2020-08
# 2025-06-20 18:08:33,853 - INFO - Progress: 58/1220 - Fetching COST news for month 2020-08
# 2025-06-20 18:08:34,630 - INFO - Found 0 articles for COST in month 2020-08
# 2025-06-20 18:08:34,832 - INFO - Progress: 59/1220 - Fetching PG news for month 2020-08
# 2025-06-20 18:08:35,559 - INFO - Found 0 articles for PG in month 2020-08
# 2025-06-20 18:08:35,761 - INFO - Progress: 60/1220 - Fetching JNJ news for month 2020-08
# 2025-06-20 18:08:36,506 - INFO - Found 0 articles for JNJ in month 2020-08
# 2025-06-20 18:08:36,707 - INFO - Progress: 61/1220 - Fetching MSFT news for month 2020-09
# 2025-06-20 18:08:37,470 - INFO - Found 2 articles for MSFT in month 2020-09
# 2025-06-20 18:08:37,672 - INFO - Progress: 62/1220 - Fetching NVDA news for month 2020-09
# 2025-06-20 18:08:38,412 - INFO - Found 2 articles for NVDA in month 2020-09
# 2025-06-20 18:08:38,613 - INFO - Progress: 63/1220 - Fetching AAPL news for month 2020-09
# 2025-06-20 18:08:39,353 - INFO - Found 17 articles for AAPL in month 2020-09
# 2025-06-20 18:08:39,554 - INFO - Progress: 64/1220 - Fetching AMZN news for month 2020-09
# 2025-06-20 18:08:40,345 - INFO - Found 7 articles for AMZN in month 2020-09
# 2025-06-20 18:08:40,547 - INFO - Progress: 65/1220 - Fetching GOOG news for month 2020-09
# 2025-06-20 18:08:41,286 - INFO - Found 7 articles for GOOG in month 2020-09
# 2025-06-20 18:08:41,488 - INFO - Progress: 66/1220 - Fetching META news for month 2020-09
# 2025-06-20 18:08:42,216 - INFO - Found 0 articles for META in month 2020-09
# 2025-06-20 18:08:42,417 - INFO - Progress: 67/1220 - Fetching AVGO news for month 2020-09
# 2025-06-20 18:08:43,195 - INFO - Found 0 articles for AVGO in month 2020-09
# 2025-06-20 18:08:43,397 - INFO - Progress: 68/1220 - Fetching BRK.B news for month 2020-09
# 2025-06-20 18:08:44,157 - INFO - Found 0 articles for BRK.B in month 2020-09
# 2025-06-20 18:08:44,358 - INFO - Progress: 69/1220 - Fetching TSLA news for month 2020-09
# 2025-06-20 18:08:45,106 - INFO - Found 2 articles for TSLA in month 2020-09
# 2025-06-20 18:08:45,308 - INFO - Progress: 70/1220 - Fetching JPM news for month 2020-09
# 2025-06-20 18:08:46,078 - INFO - Found 0 articles for JPM in month 2020-09
# 2025-06-20 18:08:46,279 - INFO - Progress: 71/1220 - Fetching WMT news for month 2020-09
# 2025-06-20 18:08:47,020 - INFO - Found 1 articles for WMT in month 2020-09
# 2025-06-20 18:08:47,221 - INFO - Progress: 72/1220 - Fetching LLY news for month 2020-09
# 2025-06-20 18:08:48,035 - INFO - Found 0 articles for LLY in month 2020-09
# 2025-06-20 18:08:48,236 - INFO - Progress: 73/1220 - Fetching V news for month 2020-09
# 2025-06-20 18:08:49,010 - INFO - Found 0 articles for V in month 2020-09
# 2025-06-20 18:08:49,212 - INFO - Progress: 74/1220 - Fetching ORCL news for month 2020-09
# 2025-06-20 18:08:50,006 - INFO - Found 1 articles for ORCL in month 2020-09
# 2025-06-20 18:08:50,209 - INFO - Progress: 75/1220 - Fetching NFLX news for month 2020-09
# 2025-06-20 18:08:50,979 - INFO - Found 8 articles for NFLX in month 2020-09
# 2025-06-20 18:08:51,180 - INFO - Progress: 76/1220 - Fetching MA news for month 2020-09
# 2025-06-20 18:08:51,933 - INFO - Found 0 articles for MA in month 2020-09
# 2025-06-20 18:08:52,134 - INFO - Progress: 77/1220 - Fetching XOM news for month 2020-09
# 2025-06-20 18:08:52,878 - INFO - Found 2 articles for XOM in month 2020-09
# 2025-06-20 18:08:53,079 - INFO - Progress: 78/1220 - Fetching COST news for month 2020-09
# 2025-06-20 18:08:53,827 - INFO - Found 2 articles for COST in month 2020-09
# 2025-06-20 18:08:54,028 - INFO - Progress: 79/1220 - Fetching PG news for month 2020-09
# 2025-06-20 18:08:54,756 - INFO - Found 0 articles for PG in month 2020-09
# 2025-06-20 18:08:54,957 - INFO - Progress: 80/1220 - Fetching JNJ news for month 2020-09
# 2025-06-20 18:08:55,692 - INFO - Found 0 articles for JNJ in month 2020-09
# 2025-06-20 18:08:55,894 - INFO - Progress: 81/1220 - Fetching MSFT news for month 2020-10
# 2025-06-20 18:08:56,671 - INFO - Found 3 articles for MSFT in month 2020-10
# 2025-06-20 18:08:56,873 - INFO - Progress: 82/1220 - Fetching NVDA news for month 2020-10
# 2025-06-20 18:08:57,624 - INFO - Found 0 articles for NVDA in month 2020-10
# 2025-06-20 18:08:57,825 - INFO - Progress: 83/1220 - Fetching AAPL news for month 2020-10
# 2025-06-20 18:08:58,566 - INFO - Found 12 articles for AAPL in month 2020-10
# 2025-06-20 18:08:58,768 - INFO - Progress: 84/1220 - Fetching AMZN news for month 2020-10
# 2025-06-20 18:08:59,543 - INFO - Found 10 articles for AMZN in month 2020-10
# 2025-06-20 18:08:59,744 - INFO - Progress: 85/1220 - Fetching GOOG news for month 2020-10
# 2025-06-20 18:09:00,481 - INFO - Found 6 articles for GOOG in month 2020-10
# 2025-06-20 18:09:00,682 - INFO - Progress: 86/1220 - Fetching META news for month 2020-10
# 2025-06-20 18:09:01,460 - INFO - Found 0 articles for META in month 2020-10
# 2025-06-20 18:09:01,661 - INFO - Progress: 87/1220 - Fetching AVGO news for month 2020-10
# 2025-06-20 18:09:02,415 - INFO - Found 0 articles for AVGO in month 2020-10
# 2025-06-20 18:09:02,617 - INFO - Progress: 88/1220 - Fetching BRK.B news for month 2020-10
# 2025-06-20 18:09:03,398 - INFO - Found 0 articles for BRK.B in month 2020-10
# 2025-06-20 18:09:03,598 - INFO - Progress: 89/1220 - Fetching TSLA news for month 2020-10
# 2025-06-20 18:09:04,370 - INFO - Found 4 articles for TSLA in month 2020-10
# 2025-06-20 18:09:04,571 - INFO - Progress: 90/1220 - Fetching JPM news for month 2020-10
# 2025-06-20 18:09:05,351 - INFO - Found 4 articles for JPM in month 2020-10
# 2025-06-20 18:09:05,553 - INFO - Progress: 91/1220 - Fetching WMT news for month 2020-10
# 2025-06-20 18:09:06,346 - INFO - Found 1 articles for WMT in month 2020-10
# 2025-06-20 18:09:06,547 - INFO - Progress: 92/1220 - Fetching LLY news for month 2020-10
# 2025-06-20 18:09:07,279 - INFO - Found 1 articles for LLY in month 2020-10
# 2025-06-20 18:09:07,481 - INFO - Progress: 93/1220 - Fetching V news for month 2020-10
# 2025-06-20 18:09:08,242 - INFO - Found 1 articles for V in month 2020-10
# 2025-06-20 18:09:08,443 - INFO - Progress: 94/1220 - Fetching ORCL news for month 2020-10
# 2025-06-20 18:09:09,218 - INFO - Found 0 articles for ORCL in month 2020-10
# 2025-06-20 18:09:09,420 - INFO - Progress: 95/1220 - Fetching NFLX news for month 2020-10
# 2025-06-20 18:09:10,181 - INFO - Found 10 articles for NFLX in month 2020-10
# 2025-06-20 18:09:10,382 - INFO - Progress: 96/1220 - Fetching MA news for month 2020-10
# 2025-06-20 18:09:11,125 - INFO - Found 1 articles for MA in month 2020-10
# 2025-06-20 18:09:11,327 - INFO - Progress: 97/1220 - Fetching XOM news for month 2020-10
# 2025-06-20 18:09:12,050 - INFO - Found 0 articles for XOM in month 2020-10
# 2025-06-20 18:09:12,251 - INFO - Progress: 98/1220 - Fetching COST news for month 2020-10
# 2025-06-20 18:09:13,003 - INFO - Found 0 articles for COST in month 2020-10
# 2025-06-20 18:09:13,204 - INFO - Progress: 99/1220 - Fetching PG news for month 2020-10
# 2025-06-20 18:09:13,946 - INFO - Found 1 articles for PG in month 2020-10
# 2025-06-20 18:09:14,147 - INFO - Progress: 100/1220 - Fetching JNJ news for month 2020-10
# 2025-06-20 18:09:14,898 - INFO - Found 1 articles for JNJ in month 2020-10
# 2025-06-20 18:09:15,099 - INFO - Progress: 101/1220 - Fetching MSFT news for month 2020-11
# 2025-06-20 18:09:15,864 - INFO - Found 1 articles for MSFT in month 2020-11
# 2025-06-20 18:09:16,064 - INFO - Progress: 102/1220 - Fetching NVDA news for month 2020-11
# 2025-06-20 18:09:16,785 - INFO - Found 1 articles for NVDA in month 2020-11
# 2025-06-20 18:09:16,986 - INFO - Progress: 103/1220 - Fetching AAPL news for month 2020-11
# 2025-06-20 18:09:17,767 - INFO - Found 6 articles for AAPL in month 2020-11
# 2025-06-20 18:09:17,968 - INFO - Progress: 104/1220 - Fetching AMZN news for month 2020-11
# 2025-06-20 18:09:18,732 - INFO - Found 5 articles for AMZN in month 2020-11
# 2025-06-20 18:09:18,934 - INFO - Progress: 105/1220 - Fetching GOOG news for month 2020-11
# 2025-06-20 18:09:19,680 - INFO - Found 3 articles for GOOG in month 2020-11
# 2025-06-20 18:09:19,882 - INFO - Progress: 106/1220 - Fetching META news for month 2020-11
# 2025-06-20 18:09:20,667 - INFO - Found 0 articles for META in month 2020-11
# 2025-06-20 18:09:20,868 - INFO - Progress: 107/1220 - Fetching AVGO news for month 2020-11
# 2025-06-20 18:09:21,623 - INFO - Found 0 articles for AVGO in month 2020-11
# 2025-06-20 18:09:21,824 - INFO - Progress: 108/1220 - Fetching BRK.B news for month 2020-11
# 2025-06-20 18:09:22,564 - INFO - Found 0 articles for BRK.B in month 2020-11
# 2025-06-20 18:09:22,764 - INFO - Progress: 109/1220 - Fetching TSLA news for month 2020-11
# 2025-06-20 18:09:23,548 - INFO - Found 1 articles for TSLA in month 2020-11
# 2025-06-20 18:09:23,749 - INFO - Progress: 110/1220 - Fetching JPM news for month 2020-11
# 2025-06-20 18:09:24,509 - INFO - Found 0 articles for JPM in month 2020-11
# 2025-06-20 18:09:24,710 - INFO - Progress: 111/1220 - Fetching WMT news for month 2020-11
# 2025-06-20 18:09:25,450 - INFO - Found 0 articles for WMT in month 2020-11
# 2025-06-20 18:09:25,651 - INFO - Progress: 112/1220 - Fetching LLY news for month 2020-11
# 2025-06-20 18:09:26,419 - INFO - Found 0 articles for LLY in month 2020-11
# 2025-06-20 18:09:26,621 - INFO - Progress: 113/1220 - Fetching V news for month 2020-11
# 2025-06-20 18:09:27,370 - INFO - Found 0 articles for V in month 2020-11
# 2025-06-20 18:09:27,571 - INFO - Progress: 114/1220 - Fetching ORCL news for month 2020-11
# 2025-06-20 18:09:28,338 - INFO - Found 0 articles for ORCL in month 2020-11
# 2025-06-20 18:09:28,539 - INFO - Progress: 115/1220 - Fetching NFLX news for month 2020-11
# 2025-06-20 18:09:29,338 - INFO - Found 8 articles for NFLX in month 2020-11
# 2025-06-20 18:09:29,539 - INFO - Progress: 116/1220 - Fetching MA news for month 2020-11
# 2025-06-20 18:09:30,285 - INFO - Found 0 articles for MA in month 2020-11
# 2025-06-20 18:09:30,487 - INFO - Progress: 117/1220 - Fetching XOM news for month 2020-11
# 2025-06-20 18:09:31,226 - INFO - Found 1 articles for XOM in month 2020-11
# 2025-06-20 18:09:31,427 - INFO - Progress: 118/1220 - Fetching COST news for month 2020-11
# 2025-06-20 18:09:32,217 - INFO - Found 0 articles for COST in month 2020-11
# 2025-06-20 18:09:32,419 - INFO - Progress: 119/1220 - Fetching PG news for month 2020-11
# 2025-06-20 18:09:33,205 - INFO - Found 0 articles for PG in month 2020-11
# 2025-06-20 18:09:33,406 - INFO - Progress: 120/1220 - Fetching JNJ news for month 2020-11
# 2025-06-20 18:09:34,149 - INFO - Found 0 articles for JNJ in month 2020-11
# 2025-06-20 18:09:34,350 - INFO - Progress: 121/1220 - Fetching MSFT news for month 2020-12
# 2025-06-20 18:09:35,150 - INFO - Found 0 articles for MSFT in month 2020-12
# 2025-06-20 18:09:35,351 - INFO - Progress: 122/1220 - Fetching NVDA news for month 2020-12
# 2025-06-20 18:09:36,072 - INFO - Found 1 articles for NVDA in month 2020-12
# 2025-06-20 18:09:36,274 - INFO - Progress: 123/1220 - Fetching AAPL news for month 2020-12
# 2025-06-20 18:09:36,996 - INFO - Found 2 articles for AAPL in month 2020-12
# 2025-06-20 18:09:37,197 - INFO - Progress: 124/1220 - Fetching AMZN news for month 2020-12
# 2025-06-20 18:09:37,957 - INFO - Found 1 articles for AMZN in month 2020-12
# 2025-06-20 18:09:38,159 - INFO - Progress: 125/1220 - Fetching GOOG news for month 2020-12
# 2025-06-20 18:09:38,948 - INFO - Found 0 articles for GOOG in month 2020-12
# 2025-06-20 18:09:39,150 - INFO - Progress: 126/1220 - Fetching META news for month 2020-12
# 2025-06-20 18:09:39,882 - INFO - Found 0 articles for META in month 2020-12
# 2025-06-20 18:09:40,083 - INFO - Progress: 127/1220 - Fetching AVGO news for month 2020-12
# 2025-06-20 18:09:40,849 - INFO - Found 0 articles for AVGO in month 2020-12
# 2025-06-20 18:09:41,051 - INFO - Progress: 128/1220 - Fetching BRK.B news for month 2020-12
# 2025-06-20 18:09:41,858 - INFO - Found 0 articles for BRK.B in month 2020-12
# 2025-06-20 18:09:42,060 - INFO - Progress: 129/1220 - Fetching TSLA news for month 2020-12
# 2025-06-20 18:09:42,815 - INFO - Found 3 articles for TSLA in month 2020-12
# 2025-06-20 18:09:43,016 - INFO - Progress: 130/1220 - Fetching JPM news for month 2020-12
# 2025-06-20 18:09:43,808 - INFO - Found 0 articles for JPM in month 2020-12
# 2025-06-20 18:09:44,010 - INFO - Progress: 131/1220 - Fetching WMT news for month 2020-12
# 2025-06-20 18:09:44,730 - INFO - Found 0 articles for WMT in month 2020-12
# 2025-06-20 18:09:44,932 - INFO - Progress: 132/1220 - Fetching LLY news for month 2020-12
# 2025-06-20 18:09:45,740 - INFO - Found 0 articles for LLY in month 2020-12
# 2025-06-20 18:09:45,941 - INFO - Progress: 133/1220 - Fetching V news for month 2020-12
# 2025-06-20 18:09:46,671 - INFO - Found 1 articles for V in month 2020-12
# 2025-06-20 18:09:46,873 - INFO - Progress: 134/1220 - Fetching ORCL news for month 2020-12
# 2025-06-20 18:09:47,598 - INFO - Found 0 articles for ORCL in month 2020-12
# 2025-06-20 18:09:47,799 - INFO - Progress: 135/1220 - Fetching NFLX news for month 2020-12
# 2025-06-20 18:09:48,548 - INFO - Found 4 articles for NFLX in month 2020-12
# 2025-06-20 18:09:48,749 - INFO - Progress: 136/1220 - Fetching MA news for month 2020-12
# 2025-06-20 18:09:49,538 - INFO - Found 2 articles for MA in month 2020-12
# 2025-06-20 18:09:49,740 - INFO - Progress: 137/1220 - Fetching XOM news for month 2020-12
# 2025-06-20 18:09:50,497 - INFO - Found 0 articles for XOM in month 2020-12
# 2025-06-20 18:09:50,699 - INFO - Progress: 138/1220 - Fetching COST news for month 2020-12
# 2025-06-20 18:09:51,442 - INFO - Found 0 articles for COST in month 2020-12
# 2025-06-20 18:09:51,645 - INFO - Progress: 139/1220 - Fetching PG news for month 2020-12
# 2025-06-20 18:09:52,361 - INFO - Found 0 articles for PG in month 2020-12
# 2025-06-20 18:09:52,567 - INFO - Progress: 140/1220 - Fetching JNJ news for month 2020-12
# 2025-06-20 18:09:53,340 - INFO - Found 0 articles for JNJ in month 2020-12
# 2025-06-20 18:09:53,545 - INFO - Progress: 141/1220 - Fetching MSFT news for month 2021-01
# 2025-06-20 18:09:54,287 - INFO - Found 3 articles for MSFT in month 2021-01
# 2025-06-20 18:09:54,489 - INFO - Progress: 142/1220 - Fetching NVDA news for month 2021-01
# 2025-06-20 18:09:55,214 - INFO - Found 0 articles for NVDA in month 2021-01
# 2025-06-20 18:09:55,419 - INFO - Progress: 143/1220 - Fetching AAPL news for month 2021-01
# 2025-06-20 18:09:56,226 - INFO - Found 8 articles for AAPL in month 2021-01
# 2025-06-20 18:09:56,429 - INFO - Progress: 144/1220 - Fetching AMZN news for month 2021-01
# 2025-06-20 18:09:57,203 - INFO - Found 3 articles for AMZN in month 2021-01
# 2025-06-20 18:09:57,410 - INFO - Progress: 145/1220 - Fetching GOOG news for month 2021-01
# 2025-06-20 18:09:58,178 - INFO - Found 3 articles for GOOG in month 2021-01
# 2025-06-20 18:09:58,381 - INFO - Progress: 146/1220 - Fetching META news for month 2021-01
# 2025-06-20 18:09:59,138 - INFO - Found 0 articles for META in month 2021-01
# 2025-06-20 18:09:59,339 - INFO - Progress: 147/1220 - Fetching AVGO news for month 2021-01
# 2025-06-20 18:10:00,086 - INFO - Found 0 articles for AVGO in month 2021-01
# 2025-06-20 18:10:00,299 - INFO - Progress: 148/1220 - Fetching BRK.B news for month 2021-01
# 2025-06-20 18:10:01,239 - INFO - Found 0 articles for BRK.B in month 2021-01
# 2025-06-20 18:10:01,441 - INFO - Progress: 149/1220 - Fetching TSLA news for month 2021-01
# 2025-06-20 18:10:02,186 - INFO - Found 4 articles for TSLA in month 2021-01
# 2025-06-20 18:10:02,394 - INFO - Progress: 150/1220 - Fetching JPM news for month 2021-01
# 2025-06-20 18:10:03,154 - INFO - Found 4 articles for JPM in month 2021-01
# 2025-06-20 18:10:03,361 - INFO - Progress: 151/1220 - Fetching WMT news for month 2021-01
# 2025-06-20 18:10:04,106 - INFO - Found 0 articles for WMT in month 2021-01
# 2025-06-20 18:10:04,311 - INFO - Progress: 152/1220 - Fetching LLY news for month 2021-01
# 2025-06-20 18:10:05,076 - INFO - Found 0 articles for LLY in month 2021-01
# 2025-06-20 18:10:05,276 - INFO - Progress: 153/1220 - Fetching V news for month 2021-01
# 2025-06-20 18:10:06,024 - INFO - Found 1 articles for V in month 2021-01
# 2025-06-20 18:10:06,229 - INFO - Progress: 154/1220 - Fetching ORCL news for month 2021-01
# 2025-06-20 18:10:07,003 - INFO - Found 0 articles for ORCL in month 2021-01
# 2025-06-20 18:10:07,211 - INFO - Progress: 155/1220 - Fetching NFLX news for month 2021-01
# 2025-06-20 18:10:07,976 - INFO - Found 7 articles for NFLX in month 2021-01
# 2025-06-20 18:10:08,183 - INFO - Progress: 156/1220 - Fetching MA news for month 2021-01
# 2025-06-20 18:10:08,937 - INFO - Found 0 articles for MA in month 2021-01
# 2025-06-20 18:10:09,144 - INFO - Progress: 157/1220 - Fetching XOM news for month 2021-01
# 2025-06-20 18:10:09,886 - INFO - Found 2 articles for XOM in month 2021-01
# 2025-06-20 18:10:10,090 - INFO - Progress: 158/1220 - Fetching COST news for month 2021-01
# 2025-06-20 18:10:10,857 - INFO - Found 0 articles for COST in month 2021-01
# 2025-06-20 18:10:11,059 - INFO - Progress: 159/1220 - Fetching PG news for month 2021-01
# 2025-06-20 18:10:11,853 - INFO - Found 0 articles for PG in month 2021-01
# 2025-06-20 18:10:12,061 - INFO - Progress: 160/1220 - Fetching JNJ news for month 2021-01
# 2025-06-20 18:10:12,791 - INFO - Found 1 articles for JNJ in month 2021-01
# 2025-06-20 18:10:12,997 - INFO - Progress: 161/1220 - Fetching MSFT news for month 2021-02
# 2025-06-20 18:10:13,753 - INFO - Found 2 articles for MSFT in month 2021-02
# 2025-06-20 18:10:13,971 - INFO - Progress: 162/1220 - Fetching NVDA news for month 2021-02
# 2025-06-20 18:10:14,721 - INFO - Found 2 articles for NVDA in month 2021-02
# 2025-06-20 18:10:14,931 - INFO - Progress: 163/1220 - Fetching AAPL news for month 2021-02
# 2025-06-20 18:10:15,720 - INFO - Found 4 articles for AAPL in month 2021-02
# 2025-06-20 18:10:15,932 - INFO - Progress: 164/1220 - Fetching AMZN news for month 2021-02
# 2025-06-20 18:10:16,704 - INFO - Found 7 articles for AMZN in month 2021-02
# 2025-06-20 18:10:16,911 - INFO - Progress: 165/1220 - Fetching GOOG news for month 2021-02
# 2025-06-20 18:10:17,681 - INFO - Found 5 articles for GOOG in month 2021-02
# 2025-06-20 18:10:17,883 - INFO - Progress: 166/1220 - Fetching META news for month 2021-02
# 2025-06-20 18:10:18,609 - INFO - Found 0 articles for META in month 2021-02
# 2025-06-20 18:10:18,819 - INFO - Progress: 167/1220 - Fetching AVGO news for month 2021-02
# 2025-06-20 18:10:19,603 - INFO - Found 0 articles for AVGO in month 2021-02
# 2025-06-20 18:10:19,807 - INFO - Progress: 168/1220 - Fetching BRK.B news for month 2021-02
# 2025-06-20 18:10:20,555 - INFO - Found 0 articles for BRK.B in month 2021-02
# 2025-06-20 18:10:20,756 - INFO - Progress: 169/1220 - Fetching TSLA news for month 2021-02
# 2025-06-20 18:10:21,573 - INFO - Found 4 articles for TSLA in month 2021-02
# 2025-06-20 18:10:21,774 - INFO - Progress: 170/1220 - Fetching JPM news for month 2021-02
# 2025-06-20 18:10:22,522 - INFO - Found 0 articles for JPM in month 2021-02
# 2025-06-20 18:10:22,730 - INFO - Progress: 171/1220 - Fetching WMT news for month 2021-02
# 2025-06-20 18:10:23,481 - INFO - Found 3 articles for WMT in month 2021-02
# 2025-06-20 18:10:23,683 - INFO - Progress: 172/1220 - Fetching LLY news for month 2021-02
# 2025-06-20 18:10:24,437 - INFO - Found 0 articles for LLY in month 2021-02
# 2025-06-20 18:10:24,643 - INFO - Progress: 173/1220 - Fetching V news for month 2021-02
# 2025-06-20 18:10:25,437 - INFO - Found 0 articles for V in month 2021-02
# 2025-06-20 18:10:25,640 - INFO - Progress: 174/1220 - Fetching ORCL news for month 2021-02
# 2025-06-20 18:10:26,375 - INFO - Found 0 articles for ORCL in month 2021-02
# 2025-06-20 18:10:26,579 - INFO - Progress: 175/1220 - Fetching NFLX news for month 2021-02
# 2025-06-20 18:10:27,379 - INFO - Found 2 articles for NFLX in month 2021-02
# 2025-06-20 18:10:27,580 - INFO - Progress: 176/1220 - Fetching MA news for month 2021-02
# 2025-06-20 18:10:28,339 - INFO - Found 0 articles for MA in month 2021-02
# 2025-06-20 18:10:28,552 - INFO - Progress: 177/1220 - Fetching XOM news for month 2021-02
# 2025-06-20 18:10:29,304 - INFO - Found 0 articles for XOM in month 2021-02
# 2025-06-20 18:10:29,515 - INFO - Progress: 178/1220 - Fetching COST news for month 2021-02
# 2025-06-20 18:10:30,303 - INFO - Found 0 articles for COST in month 2021-02
# 2025-06-20 18:10:30,507 - INFO - Progress: 179/1220 - Fetching PG news for month 2021-02
# 2025-06-20 18:10:31,244 - INFO - Found 0 articles for PG in month 2021-02
# 2025-06-20 18:10:31,447 - INFO - Progress: 180/1220 - Fetching JNJ news for month 2021-02
# 2025-06-20 18:10:32,204 - INFO - Found 2 articles for JNJ in month 2021-02
# 2025-06-20 18:10:32,413 - INFO - Progress: 181/1220 - Fetching MSFT news for month 2021-03
# 2025-06-20 18:10:33,156 - INFO - Found 8 articles for MSFT in month 2021-03
# 2025-06-20 18:10:33,357 - INFO - Progress: 182/1220 - Fetching NVDA news for month 2021-03
# 2025-06-20 18:10:34,121 - INFO - Found 1 articles for NVDA in month 2021-03
# 2025-06-20 18:10:34,335 - INFO - Progress: 183/1220 - Fetching AAPL news for month 2021-03
# 2025-06-20 18:10:35,138 - INFO - Found 10 articles for AAPL in month 2021-03
# 2025-06-20 18:10:35,343 - INFO - Progress: 184/1220 - Fetching AMZN news for month 2021-03
# 2025-06-20 18:10:36,088 - INFO - Found 4 articles for AMZN in month 2021-03
# 2025-06-20 18:10:36,292 - INFO - Progress: 185/1220 - Fetching GOOG news for month 2021-03
# 2025-06-20 18:10:37,037 - INFO - Found 5 articles for GOOG in month 2021-03
# 2025-06-20 18:10:37,238 - INFO - Progress: 186/1220 - Fetching META news for month 2021-03
# 2025-06-20 18:10:37,994 - INFO - Found 0 articles for META in month 2021-03
# 2025-06-20 18:10:38,198 - INFO - Progress: 187/1220 - Fetching AVGO news for month 2021-03
# 2025-06-20 18:10:39,005 - INFO - Found 0 articles for AVGO in month 2021-03
# 2025-06-20 18:10:39,212 - INFO - Progress: 188/1220 - Fetching BRK.B news for month 2021-03
# 2025-06-20 18:10:39,977 - INFO - Found 0 articles for BRK.B in month 2021-03
# 2025-06-20 18:10:40,179 - INFO - Progress: 189/1220 - Fetching TSLA news for month 2021-03
# 2025-06-20 18:10:40,922 - INFO - Found 7 articles for TSLA in month 2021-03
# 2025-06-20 18:10:41,136 - INFO - Progress: 190/1220 - Fetching JPM news for month 2021-03
# 2025-06-20 18:10:41,920 - INFO - Found 0 articles for JPM in month 2021-03
# 2025-06-20 18:10:42,137 - INFO - Progress: 191/1220 - Fetching WMT news for month 2021-03
# 2025-06-20 18:10:42,877 - INFO - Found 0 articles for WMT in month 2021-03
# 2025-06-20 18:10:43,078 - INFO - Progress: 192/1220 - Fetching LLY news for month 2021-03
# 2025-06-20 18:10:43,828 - INFO - Found 0 articles for LLY in month 2021-03
# 2025-06-20 18:10:44,034 - INFO - Progress: 193/1220 - Fetching V news for month 2021-03
# 2025-06-20 18:10:44,808 - INFO - Found 1 articles for V in month 2021-03
# 2025-06-20 18:10:45,017 - INFO - Progress: 194/1220 - Fetching ORCL news for month 2021-03
# 2025-06-20 18:10:45,776 - INFO - Found 0 articles for ORCL in month 2021-03
# 2025-06-20 18:10:45,978 - INFO - Progress: 195/1220 - Fetching NFLX news for month 2021-03
# 2025-06-20 18:10:46,787 - INFO - Found 6 articles for NFLX in month 2021-03
# 2025-06-20 18:10:46,989 - INFO - Progress: 196/1220 - Fetching MA news for month 2021-03
# 2025-06-20 18:10:47,756 - INFO - Found 0 articles for MA in month 2021-03
# 2025-06-20 18:10:47,960 - INFO - Progress: 197/1220 - Fetching XOM news for month 2021-03
# 2025-06-20 18:10:48,783 - INFO - Found 1 articles for XOM in month 2021-03
# 2025-06-20 18:10:48,986 - INFO - Progress: 198/1220 - Fetching COST news for month 2021-03
# 2025-06-20 18:10:49,780 - INFO - Found 0 articles for COST in month 2021-03
# 2025-06-20 18:10:49,981 - INFO - Progress: 199/1220 - Fetching PG news for month 2021-03
# 2025-06-20 18:10:50,737 - INFO - Found 0 articles for PG in month 2021-03
# 2025-06-20 18:10:50,941 - INFO - Progress: 200/1220 - Fetching JNJ news for month 2021-03
# 2025-06-20 18:10:51,737 - INFO - Found 3 articles for JNJ in month 2021-03
# 2025-06-20 18:10:51,949 - INFO - Progress: 201/1220 - Fetching MSFT news for month 2021-04
# 2025-06-20 18:10:52,980 - INFO - Found 114 articles for MSFT in month 2021-04
# 2025-06-20 18:10:53,181 - INFO - Progress: 202/1220 - Fetching NVDA news for month 2021-04
# 2025-06-20 18:10:54,236 - INFO - Found 63 articles for NVDA in month 2021-04
# 2025-06-20 18:10:54,438 - INFO - Progress: 203/1220 - Fetching AAPL news for month 2021-04
# 2025-06-20 18:10:55,740 - INFO - Found 198 articles for AAPL in month 2021-04
# 2025-06-20 18:10:55,942 - INFO - Progress: 204/1220 - Fetching AMZN news for month 2021-04
# 2025-06-20 18:10:57,408 - INFO - Found 197 articles for AMZN in month 2021-04
# 2025-06-20 18:10:57,614 - INFO - Progress: 205/1220 - Fetching GOOG news for month 2021-04
# 2025-06-20 18:10:58,610 - INFO - Found 73 articles for GOOG in month 2021-04
# 2025-06-20 18:10:58,816 - INFO - Progress: 206/1220 - Fetching META news for month 2021-04
# 2025-06-20 18:10:59,587 - INFO - Found 0 articles for META in month 2021-04
# 2025-06-20 18:10:59,789 - INFO - Progress: 207/1220 - Fetching AVGO news for month 2021-04
# 2025-06-20 18:11:00,546 - INFO - Found 7 articles for AVGO in month 2021-04
# 2025-06-20 18:11:00,750 - INFO - Progress: 208/1220 - Fetching BRK.B news for month 2021-04
# 2025-06-20 18:11:01,521 - INFO - Found 24 articles for BRK.B in month 2021-04
# 2025-06-20 18:11:01,732 - INFO - Progress: 209/1220 - Fetching TSLA news for month 2021-04
# 2025-06-20 18:11:03,141 - INFO - Found 155 articles for TSLA in month 2021-04
# 2025-06-20 18:11:03,350 - INFO - Progress: 210/1220 - Fetching JPM news for month 2021-04
# 2025-06-20 18:11:04,137 - INFO - Found 28 articles for JPM in month 2021-04
# 2025-06-20 18:11:04,342 - INFO - Progress: 211/1220 - Fetching WMT news for month 2021-04
# 2025-06-20 18:11:05,358 - INFO - Found 25 articles for WMT in month 2021-04
# 2025-06-20 18:11:05,569 - INFO - Progress: 212/1220 - Fetching LLY news for month 2021-04
# 2025-06-20 18:11:06,354 - INFO - Found 18 articles for LLY in month 2021-04
# 2025-06-20 18:11:06,560 - INFO - Progress: 213/1220 - Fetching V news for month 2021-04
# 2025-06-20 18:11:07,539 - INFO - Found 29 articles for V in month 2021-04
# 2025-06-20 18:11:07,745 - INFO - Progress: 214/1220 - Fetching ORCL news for month 2021-04
# 2025-06-20 18:11:08,504 - INFO - Found 5 articles for ORCL in month 2021-04
# 2025-06-20 18:11:08,711 - INFO - Progress: 215/1220 - Fetching NFLX news for month 2021-04
# 2025-06-20 18:11:09,687 - INFO - Found 71 articles for NFLX in month 2021-04
# 2025-06-20 18:11:09,901 - INFO - Progress: 216/1220 - Fetching MA news for month 2021-04
# 2025-06-20 18:11:10,954 - INFO - Found 19 articles for MA in month 2021-04
# 2025-06-20 18:11:11,157 - INFO - Progress: 217/1220 - Fetching XOM news for month 2021-04
# 2025-06-20 18:11:12,172 - INFO - Found 57 articles for XOM in month 2021-04
# 2025-06-20 18:11:12,374 - INFO - Progress: 218/1220 - Fetching COST news for month 2021-04
# 2025-06-20 18:11:13,143 - INFO - Found 7 articles for COST in month 2021-04
# 2025-06-20 18:11:13,346 - INFO - Progress: 219/1220 - Fetching PG news for month 2021-04
# 2025-06-20 18:11:14,146 - INFO - Found 17 articles for PG in month 2021-04
# 2025-06-20 18:11:14,348 - INFO - Progress: 220/1220 - Fetching JNJ news for month 2021-04
# 2025-06-20 18:11:15,379 - INFO - Found 66 articles for JNJ in month 2021-04
# 2025-06-20 18:11:15,582 - INFO - Progress: 221/1220 - Fetching MSFT news for month 2021-05
# 2025-06-20 18:11:16,926 - INFO - Found 251 articles for MSFT in month 2021-05
# 2025-06-20 18:11:17,129 - INFO - Progress: 222/1220 - Fetching NVDA news for month 2021-05
# 2025-06-20 18:11:18,444 - INFO - Found 275 articles for NVDA in month 2021-05
# 2025-06-20 18:11:18,645 - INFO - Progress: 223/1220 - Fetching AAPL news for month 2021-05
# 2025-06-20 18:11:20,220 - INFO - Found 406 articles for AAPL in month 2021-05
# 2025-06-20 18:11:20,428 - INFO - Progress: 224/1220 - Fetching AMZN news for month 2021-05
# 2025-06-20 18:11:21,924 - INFO - Found 472 articles for AMZN in month 2021-05
# 2025-06-20 18:11:22,132 - INFO - Progress: 225/1220 - Fetching GOOG news for month 2021-05
# 2025-06-20 18:11:23,367 - INFO - Found 173 articles for GOOG in month 2021-05
# 2025-06-20 18:11:23,570 - INFO - Progress: 226/1220 - Fetching META news for month 2021-05
# 2025-06-20 18:11:24,337 - INFO - Found 0 articles for META in month 2021-05
# 2025-06-20 18:11:24,540 - INFO - Progress: 227/1220 - Fetching AVGO news for month 2021-05
# 2025-06-20 18:11:25,287 - INFO - Found 19 articles for AVGO in month 2021-05
# 2025-06-20 18:11:25,490 - INFO - Progress: 228/1220 - Fetching BRK.B news for month 2021-05
# 2025-06-20 18:11:26,521 - INFO - Found 106 articles for BRK.B in month 2021-05
# 2025-06-20 18:11:26,727 - INFO - Progress: 229/1220 - Fetching TSLA news for month 2021-05
# 2025-06-20 18:11:28,343 - INFO - Found 527 articles for TSLA in month 2021-05
# 2025-06-20 18:11:28,545 - INFO - Progress: 230/1220 - Fetching JPM news for month 2021-05
# 2025-06-20 18:11:29,791 - INFO - Found 123 articles for JPM in month 2021-05
# 2025-06-20 18:11:30,003 - INFO - Progress: 231/1220 - Fetching WMT news for month 2021-05
# 2025-06-20 18:11:31,222 - INFO - Found 186 articles for WMT in month 2021-05
# 2025-06-20 18:11:31,424 - INFO - Progress: 232/1220 - Fetching LLY news for month 2021-05
# 2025-06-20 18:11:32,205 - INFO - Found 39 articles for LLY in month 2021-05
# 2025-06-20 18:11:32,415 - INFO - Progress: 233/1220 - Fetching V news for month 2021-05
# 2025-06-20 18:11:33,421 - INFO - Found 54 articles for V in month 2021-05
# 2025-06-20 18:11:33,635 - INFO - Progress: 234/1220 - Fetching ORCL news for month 2021-05
# 2025-06-20 18:11:34,426 - INFO - Found 27 articles for ORCL in month 2021-05
# 2025-06-20 18:11:34,632 - INFO - Progress: 235/1220 - Fetching NFLX news for month 2021-05
# 2025-06-20 18:11:35,899 - INFO - Found 185 articles for NFLX in month 2021-05
# 2025-06-20 18:11:36,101 - INFO - Progress: 236/1220 - Fetching MA news for month 2021-05
# 2025-06-20 18:11:37,121 - INFO - Found 53 articles for MA in month 2021-05
# 2025-06-20 18:11:37,325 - INFO - Progress: 237/1220 - Fetching XOM news for month 2021-05
# 2025-06-20 18:11:38,354 - INFO - Found 75 articles for XOM in month 2021-05
# 2025-06-20 18:11:38,561 - INFO - Progress: 238/1220 - Fetching COST news for month 2021-05
# 2025-06-20 18:11:39,638 - INFO - Found 85 articles for COST in month 2021-05
# 2025-06-20 18:11:39,840 - INFO - Progress: 239/1220 - Fetching PG news for month 2021-05
# 2025-06-20 18:11:40,823 - INFO - Found 40 articles for PG in month 2021-05
# 2025-06-20 18:11:41,027 - INFO - Progress: 240/1220 - Fetching JNJ news for month 2021-05
# 2025-06-20 18:11:42,254 - INFO - Found 163 articles for JNJ in month 2021-05
# 2025-06-20 18:11:42,457 - INFO - Progress: 241/1220 - Fetching MSFT news for month 2021-06
# 2025-06-20 18:11:43,855 - INFO - Found 312 articles for MSFT in month 2021-06
# 2025-06-20 18:11:44,060 - INFO - Progress: 242/1220 - Fetching NVDA news for month 2021-06
# 2025-06-20 18:11:45,338 - INFO - Found 193 articles for NVDA in month 2021-06
# 2025-06-20 18:11:45,540 - INFO - Progress: 243/1220 - Fetching AAPL news for month 2021-06
# 2025-06-20 18:11:47,091 - INFO - Found 464 articles for AAPL in month 2021-06
# 2025-06-20 18:11:47,303 - INFO - Progress: 244/1220 - Fetching AMZN news for month 2021-06
# 2025-06-20 18:11:48,940 - INFO - Found 619 articles for AMZN in month 2021-06
# 2025-06-20 18:11:49,142 - INFO - Progress: 245/1220 - Fetching GOOG news for month 2021-06
# 2025-06-20 18:11:50,489 - INFO - Found 199 articles for GOOG in month 2021-06
# 2025-06-20 18:11:50,694 - INFO - Progress: 246/1220 - Fetching META news for month 2021-06
# 2025-06-20 18:11:51,454 - INFO - Found 0 articles for META in month 2021-06
# 2025-06-20 18:11:51,658 - INFO - Progress: 247/1220 - Fetching AVGO news for month 2021-06
# 2025-06-20 18:11:52,597 - INFO - Found 36 articles for AVGO in month 2021-06
# 2025-06-20 18:11:52,801 - INFO - Progress: 248/1220 - Fetching BRK.B news for month 2021-06
# 2025-06-20 18:11:53,848 - INFO - Found 67 articles for BRK.B in month 2021-06
# 2025-06-20 18:11:54,051 - INFO - Progress: 249/1220 - Fetching TSLA news for month 2021-06
# 2025-06-20 18:11:55,672 - INFO - Found 520 articles for TSLA in month 2021-06
# 2025-06-20 18:11:55,887 - INFO - Progress: 250/1220 - Fetching JPM news for month 2021-06
# 2025-06-20 18:11:56,949 - INFO - Found 143 articles for JPM in month 2021-06
# 2025-06-20 18:11:57,150 - INFO - Progress: 251/1220 - Fetching WMT news for month 2021-06
# 2025-06-20 18:11:58,176 - INFO - Found 135 articles for WMT in month 2021-06
# 2025-06-20 18:11:58,381 - INFO - Progress: 252/1220 - Fetching LLY news for month 2021-06
# 2025-06-20 18:11:59,454 - INFO - Found 61 articles for LLY in month 2021-06
# 2025-06-20 18:11:59,657 - INFO - Progress: 253/1220 - Fetching V news for month 2021-06
# 2025-06-20 18:12:00,635 - INFO - Found 73 articles for V in month 2021-06
# 2025-06-20 18:12:00,836 - INFO - Progress: 254/1220 - Fetching ORCL news for month 2021-06
# 2025-06-20 18:12:01,854 - INFO - Found 57 articles for ORCL in month 2021-06
# 2025-06-20 18:12:02,055 - INFO - Progress: 255/1220 - Fetching NFLX news for month 2021-06
# 2025-06-20 18:12:03,322 - INFO - Found 169 articles for NFLX in month 2021-06
# 2025-06-20 18:12:03,526 - INFO - Progress: 256/1220 - Fetching MA news for month 2021-06
# 2025-06-20 18:12:04,489 - INFO - Found 50 articles for MA in month 2021-06
# 2025-06-20 18:12:04,701 - INFO - Progress: 257/1220 - Fetching XOM news for month 2021-06
# 2025-06-20 18:12:05,672 - INFO - Found 102 articles for XOM in month 2021-06
# 2025-06-20 18:12:05,880 - INFO - Progress: 258/1220 - Fetching COST news for month 2021-06
# 2025-06-20 18:12:06,938 - INFO - Found 71 articles for COST in month 2021-06
# 2025-06-20 18:12:07,144 - INFO - Progress: 259/1220 - Fetching PG news for month 2021-06
# 2025-06-20 18:12:07,921 - INFO - Found 34 articles for PG in month 2021-06
# 2025-06-20 18:12:08,135 - INFO - Progress: 260/1220 - Fetching JNJ news for month 2021-06
# 2025-06-20 18:12:09,138 - INFO - Found 140 articles for JNJ in month 2021-06
# 2025-06-20 18:12:09,339 - INFO - Progress: 261/1220 - Fetching MSFT news for month 2021-07
# 2025-06-20 18:12:10,954 - INFO - Found 373 articles for MSFT in month 2021-07
# 2025-06-20 18:12:11,156 - INFO - Progress: 262/1220 - Fetching NVDA news for month 2021-07
# 2025-06-20 18:12:12,421 - INFO - Found 199 articles for NVDA in month 2021-07
# 2025-06-20 18:12:12,626 - INFO - Progress: 263/1220 - Fetching AAPL news for month 2021-07
# 2025-06-20 18:12:14,371 - INFO - Found 607 articles for AAPL in month 2021-07
# 2025-06-20 18:12:14,574 - INFO - Progress: 264/1220 - Fetching AMZN news for month 2021-07
# 2025-06-20 18:12:16,587 - INFO - Found 630 articles for AMZN in month 2021-07
# 2025-06-20 18:12:16,790 - INFO - Progress: 265/1220 - Fetching GOOG news for month 2021-07
# 2025-06-20 18:12:18,084 - INFO - Found 239 articles for GOOG in month 2021-07
# 2025-06-20 18:12:18,288 - INFO - Progress: 266/1220 - Fetching META news for month 2021-07
# 2025-06-20 18:12:19,023 - INFO - Found 2 articles for META in month 2021-07
# 2025-06-20 18:12:19,228 - INFO - Progress: 267/1220 - Fetching AVGO news for month 2021-07
# 2025-06-20 18:12:20,205 - INFO - Found 34 articles for AVGO in month 2021-07
# 2025-06-20 18:12:20,409 - INFO - Progress: 268/1220 - Fetching BRK.B news for month 2021-07
# 2025-06-20 18:12:21,453 - INFO - Found 50 articles for BRK.B in month 2021-07
# 2025-06-20 18:12:21,655 - INFO - Progress: 269/1220 - Fetching TSLA news for month 2021-07
# 2025-06-20 18:12:23,491 - INFO - Found 531 articles for TSLA in month 2021-07
# 2025-06-20 18:12:23,703 - INFO - Progress: 270/1220 - Fetching JPM news for month 2021-07
# 2025-06-20 18:12:24,961 - INFO - Found 171 articles for JPM in month 2021-07
# 2025-06-20 18:12:25,172 - INFO - Progress: 271/1220 - Fetching WMT news for month 2021-07
# 2025-06-20 18:12:26,389 - INFO - Found 127 articles for WMT in month 2021-07
# 2025-06-20 18:12:26,592 - INFO - Progress: 272/1220 - Fetching LLY news for month 2021-07
# 2025-06-20 18:12:27,610 - INFO - Found 51 articles for LLY in month 2021-07
# 2025-06-20 18:12:27,814 - INFO - Progress: 273/1220 - Fetching V news for month 2021-07
# 2025-06-20 18:12:28,822 - INFO - Found 102 articles for V in month 2021-07
# 2025-06-20 18:12:29,029 - INFO - Progress: 274/1220 - Fetching ORCL news for month 2021-07
# 2025-06-20 18:12:29,974 - INFO - Found 37 articles for ORCL in month 2021-07
# 2025-06-20 18:12:30,186 - INFO - Progress: 275/1220 - Fetching NFLX news for month 2021-07
# 2025-06-20 18:12:31,677 - INFO - Found 311 articles for NFLX in month 2021-07
# 2025-06-20 18:12:31,883 - INFO - Progress: 276/1220 - Fetching MA news for month 2021-07
# 2025-06-20 18:12:32,938 - INFO - Found 60 articles for MA in month 2021-07
# 2025-06-20 18:12:33,146 - INFO - Progress: 277/1220 - Fetching XOM news for month 2021-07
# 2025-06-20 18:12:34,153 - INFO - Found 90 articles for XOM in month 2021-07
# 2025-06-20 18:12:34,354 - INFO - Progress: 278/1220 - Fetching COST news for month 2021-07
# 2025-06-20 18:12:35,388 - INFO - Found 67 articles for COST in month 2021-07
# 2025-06-20 18:12:35,590 - INFO - Progress: 279/1220 - Fetching PG news for month 2021-07
# 2025-06-20 18:12:36,641 - INFO - Found 49 articles for PG in month 2021-07
# 2025-06-20 18:12:36,843 - INFO - Progress: 280/1220 - Fetching JNJ news for month 2021-07
# 2025-06-20 18:12:38,085 - INFO - Found 194 articles for JNJ in month 2021-07
# 2025-06-20 18:12:38,287 - INFO - Progress: 281/1220 - Fetching MSFT news for month 2021-08
# 2025-06-20 18:12:39,910 - INFO - Found 338 articles for MSFT in month 2021-08
# 2025-06-20 18:12:40,114 - INFO - Progress: 282/1220 - Fetching NVDA news for month 2021-08
# 2025-06-20 18:12:41,464 - INFO - Found 215 articles for NVDA in month 2021-08
# 2025-06-20 18:12:41,671 - INFO - Progress: 283/1220 - Fetching AAPL news for month 2021-08
# 2025-06-20 18:12:43,455 - INFO - Found 506 articles for AAPL in month 2021-08
# 2025-06-20 18:12:43,666 - INFO - Progress: 284/1220 - Fetching AMZN news for month 2021-08
# 2025-06-20 18:12:45,497 - INFO - Found 519 articles for AMZN in month 2021-08
# 2025-06-20 18:12:45,701 - INFO - Progress: 285/1220 - Fetching GOOG news for month 2021-08
# 2025-06-20 18:12:46,944 - INFO - Found 244 articles for GOOG in month 2021-08
# 2025-06-20 18:12:47,153 - INFO - Progress: 286/1220 - Fetching META news for month 2021-08
# 2025-06-20 18:12:47,935 - INFO - Found 4 articles for META in month 2021-08
# 2025-06-20 18:12:48,138 - INFO - Progress: 287/1220 - Fetching AVGO news for month 2021-08
# 2025-06-20 18:12:49,171 - INFO - Found 34 articles for AVGO in month 2021-08
# ...
# 2025-06-20 18:32:18,910 - INFO - Found 36 articles for AVGO in month 2025-02
# 2025-06-20 18:32:19,112 - INFO - Progress: 1128/1220 - Fetching BRK.B news for month 2025-02
# 2025-06-20 18:32:20,137 - INFO - Found 52 articles for BRK.B in month 2025-02
# 2025-06-20 18:32:20,344 - INFO - Progress: 1129/1220 - Fetching TSLA news for month 2025-02
# 2025-06-20 18:32:21,553 - INFO - Found 82 articles for TSLA in month 2025-02
# 2025-06-20 18:32:21,762 - INFO - Progress: 1130/1220 - Fetching JPM news for month 2025-02
# 2025-06-20 18:32:22,756 - INFO - Found 19 articles for JPM in month 2025-02
# 2025-06-20 18:32:22,968 - INFO - Progress: 1131/1220 - Fetching WMT news for month 2025-02
# 2025-06-20 18:32:23,979 - INFO - Found 39 articles for WMT in month 2025-02
# 2025-06-20 18:32:24,185 - INFO - Progress: 1132/1220 - Fetching LLY news for month 2025-02
# 2025-06-20 18:32:25,204 - INFO - Found 29 articles for LLY in month 2025-02
# 2025-06-20 18:32:25,405 - INFO - Progress: 1133/1220 - Fetching V news for month 2025-02
# 2025-06-20 18:32:26,378 - INFO - Found 16 articles for V in month 2025-02
# 2025-06-20 18:32:26,581 - INFO - Progress: 1134/1220 - Fetching ORCL news for month 2025-02
# 2025-06-20 18:32:27,589 - INFO - Found 36 articles for ORCL in month 2025-02
# 2025-06-20 18:32:27,799 - INFO - Progress: 1135/1220 - Fetching NFLX news for month 2025-02
# 2025-06-20 18:32:28,753 - INFO - Found 29 articles for NFLX in month 2025-02
# 2025-06-20 18:32:28,970 - INFO - Progress: 1136/1220 - Fetching MA news for month 2025-02
# 2025-06-20 18:32:29,953 - INFO - Found 13 articles for MA in month 2025-02
# 2025-06-20 18:32:30,170 - INFO - Progress: 1137/1220 - Fetching XOM news for month 2025-02
# 2025-06-20 18:32:30,976 - INFO - Found 13 articles for XOM in month 2025-02
# 2025-06-20 18:32:31,178 - INFO - Progress: 1138/1220 - Fetching COST news for month 2025-02
# 2025-06-20 18:32:32,140 - INFO - Found 18 articles for COST in month 2025-02
# 2025-06-20 18:32:32,343 - INFO - Progress: 1139/1220 - Fetching PG news for month 2025-02
# 2025-06-20 18:32:33,104 - INFO - Found 5 articles for PG in month 2025-02
# 2025-06-20 18:32:33,308 - INFO - Progress: 1140/1220 - Fetching JNJ news for month 2025-02
# 2025-06-20 18:32:34,379 - INFO - Found 32 articles for JNJ in month 2025-02
# 2025-06-20 18:32:34,581 - INFO - Progress: 1141/1220 - Fetching MSFT news for month 2025-03
# 2025-06-20 18:32:35,836 - INFO - Found 109 articles for MSFT in month 2025-03
# 2025-06-20 18:32:36,038 - INFO - Progress: 1142/1220 - Fetching NVDA news for month 2025-03
# 2025-06-20 18:32:37,604 - INFO - Found 268 articles for NVDA in month 2025-03
# 2025-06-20 18:32:37,805 - INFO - Progress: 1143/1220 - Fetching AAPL news for month 2025-03
# 2025-06-20 18:32:39,056 - INFO - Found 93 articles for AAPL in month 2025-03
# 2025-06-20 18:32:39,269 - INFO - Progress: 1144/1220 - Fetching AMZN news for month 2025-03
# 2025-06-20 18:32:40,579 - INFO - Found 166 articles for AMZN in month 2025-03
# 2025-06-20 18:32:40,780 - INFO - Progress: 1145/1220 - Fetching GOOG news for month 2025-03
# 2025-06-20 18:32:42,138 - INFO - Found 142 articles for GOOG in month 2025-03
# 2025-06-20 18:32:42,341 - INFO - Progress: 1146/1220 - Fetching META news for month 2025-03
# 2025-06-20 18:32:43,345 - INFO - Found 64 articles for META in month 2025-03
# 2025-06-20 18:32:43,547 - INFO - Progress: 1147/1220 - Fetching AVGO news for month 2025-03
# 2025-06-20 18:32:44,614 - INFO - Found 57 articles for AVGO in month 2025-03
# 2025-06-20 18:32:44,819 - INFO - Progress: 1148/1220 - Fetching BRK.B news for month 2025-03
# 2025-06-20 18:32:45,794 - INFO - Found 68 articles for BRK.B in month 2025-03
# 2025-06-20 18:32:45,996 - INFO - Progress: 1149/1220 - Fetching TSLA news for month 2025-03
# 2025-06-20 18:32:47,258 - INFO - Found 83 articles for TSLA in month 2025-03
# 2025-06-20 18:32:47,466 - INFO - Progress: 1150/1220 - Fetching JPM news for month 2025-03
# 2025-06-20 18:32:48,475 - INFO - Found 21 articles for JPM in month 2025-03
# 2025-06-20 18:32:48,677 - INFO - Progress: 1151/1220 - Fetching WMT news for month 2025-03
# 2025-06-20 18:32:49,642 - INFO - Found 23 articles for WMT in month 2025-03
# 2025-06-20 18:32:49,850 - INFO - Progress: 1152/1220 - Fetching LLY news for month 2025-03
# 2025-06-20 18:32:50,809 - INFO - Found 24 articles for LLY in month 2025-03
# 2025-06-20 18:32:51,014 - INFO - Progress: 1153/1220 - Fetching V news for month 2025-03
# 2025-06-20 18:32:51,802 - INFO - Found 12 articles for V in month 2025-03
# 2025-06-20 18:32:52,004 - INFO - Progress: 1154/1220 - Fetching ORCL news for month 2025-03
# 2025-06-20 18:32:53,088 - INFO - Found 28 articles for ORCL in month 2025-03
# 2025-06-20 18:32:53,289 - INFO - Progress: 1155/1220 - Fetching NFLX news for month 2025-03
# 2025-06-20 18:32:54,287 - INFO - Found 16 articles for NFLX in month 2025-03
# 2025-06-20 18:32:54,493 - INFO - Progress: 1156/1220 - Fetching MA news for month 2025-03
# 2025-06-20 18:32:55,237 - INFO - Found 2 articles for MA in month 2025-03
# 2025-06-20 18:32:55,454 - INFO - Progress: 1157/1220 - Fetching XOM news for month 2025-03
# 2025-06-20 18:32:56,446 - INFO - Found 17 articles for XOM in month 2025-03
# 2025-06-20 18:32:56,647 - INFO - Progress: 1158/1220 - Fetching COST news for month 2025-03
# 2025-06-20 18:32:57,655 - INFO - Found 21 articles for COST in month 2025-03
# 2025-06-20 18:32:57,858 - INFO - Progress: 1159/1220 - Fetching PG news for month 2025-03
# 2025-06-20 18:32:58,621 - INFO - Found 8 articles for PG in month 2025-03
# 2025-06-20 18:32:58,824 - INFO - Progress: 1160/1220 - Fetching JNJ news for month 2025-03
# 2025-06-20 18:32:59,788 - INFO - Found 16 articles for JNJ in month 2025-03
# 2025-06-20 18:33:00,004 - INFO - Progress: 1161/1220 - Fetching MSFT news for month 2025-04
# 2025-06-20 18:33:01,287 - INFO - Found 106 articles for MSFT in month 2025-04
# 2025-06-20 18:33:01,504 - INFO - Progress: 1162/1220 - Fetching NVDA news for month 2025-04
# 2025-06-20 18:33:03,003 - INFO - Found 225 articles for NVDA in month 2025-04
# 2025-06-20 18:33:03,204 - INFO - Progress: 1163/1220 - Fetching AAPL news for month 2025-04
# 2025-06-20 18:33:04,520 - INFO - Found 130 articles for AAPL in month 2025-04
# 2025-06-20 18:33:04,722 - INFO - Progress: 1164/1220 - Fetching AMZN news for month 2025-04
# 2025-06-20 18:33:06,037 - INFO - Found 183 articles for AMZN in month 2025-04
# 2025-06-20 18:33:06,244 - INFO - Progress: 1165/1220 - Fetching GOOG news for month 2025-04
# 2025-06-20 18:33:07,480 - INFO - Found 154 articles for GOOG in month 2025-04
# 2025-06-20 18:33:07,682 - INFO - Progress: 1166/1220 - Fetching META news for month 2025-04
# 2025-06-20 18:33:08,687 - INFO - Found 68 articles for META in month 2025-04
# 2025-06-20 18:33:08,889 - INFO - Progress: 1167/1220 - Fetching AVGO news for month 2025-04
# 2025-06-20 18:33:09,921 - INFO - Found 59 articles for AVGO in month 2025-04
# 2025-06-20 18:33:10,126 - INFO - Progress: 1168/1220 - Fetching BRK.B news for month 2025-04
# 2025-06-20 18:33:11,206 - INFO - Found 79 articles for BRK.B in month 2025-04
# 2025-06-20 18:33:11,407 - INFO - Progress: 1169/1220 - Fetching TSLA news for month 2025-04
# 2025-06-20 18:33:12,790 - INFO - Found 106 articles for TSLA in month 2025-04
# 2025-06-20 18:33:12,999 - INFO - Progress: 1170/1220 - Fetching JPM news for month 2025-04
# 2025-06-20 18:33:14,004 - INFO - Found 48 articles for JPM in month 2025-04
# 2025-06-20 18:33:14,209 - INFO - Progress: 1171/1220 - Fetching WMT news for month 2025-04
# 2025-06-20 18:33:15,269 - INFO - Found 29 articles for WMT in month 2025-04
# 2025-06-20 18:33:15,471 - INFO - Progress: 1172/1220 - Fetching LLY news for month 2025-04
# 2025-06-20 18:33:16,521 - INFO - Found 39 articles for LLY in month 2025-04
# 2025-06-20 18:33:16,732 - INFO - Progress: 1173/1220 - Fetching V news for month 2025-04
# 2025-06-20 18:33:17,704 - INFO - Found 23 articles for V in month 2025-04
# 2025-06-20 18:33:17,904 - INFO - Progress: 1174/1220 - Fetching ORCL news for month 2025-04
# 2025-06-20 18:33:18,888 - INFO - Found 18 articles for ORCL in month 2025-04
# 2025-06-20 18:33:19,101 - INFO - Progress: 1175/1220 - Fetching NFLX news for month 2025-04
# 2025-06-20 18:33:20,091 - INFO - Found 33 articles for NFLX in month 2025-04
# 2025-06-20 18:33:20,295 - INFO - Progress: 1176/1220 - Fetching MA news for month 2025-04
# 2025-06-20 18:33:21,308 - INFO - Found 15 articles for MA in month 2025-04
# 2025-06-20 18:33:21,509 - INFO - Progress: 1177/1220 - Fetching XOM news for month 2025-04
# 2025-06-20 18:33:22,479 - INFO - Found 18 articles for XOM in month 2025-04
# 2025-06-20 18:33:22,681 - INFO - Progress: 1178/1220 - Fetching COST news for month 2025-04
# 2025-06-20 18:33:23,678 - INFO - Found 21 articles for COST in month 2025-04
# 2025-06-20 18:33:23,880 - INFO - Progress: 1179/1220 - Fetching PG news for month 2025-04
# 2025-06-20 18:33:24,637 - INFO - Found 10 articles for PG in month 2025-04
# 2025-06-20 18:33:24,851 - INFO - Progress: 1180/1220 - Fetching JNJ news for month 2025-04
# 2025-06-20 18:33:25,840 - INFO - Found 30 articles for JNJ in month 2025-04
# 2025-06-20 18:33:26,042 - INFO - Progress: 1181/1220 - Fetching MSFT news for month 2025-05
# 2025-06-20 18:33:27,285 - INFO - Found 115 articles for MSFT in month 2025-05
# 2025-06-20 18:33:27,488 - INFO - Progress: 1182/1220 - Fetching NVDA news for month 2025-05
# 2025-06-20 18:33:29,058 - INFO - Found 237 articles for NVDA in month 2025-05
# 2025-06-20 18:33:29,260 - INFO - Progress: 1183/1220 - Fetching AAPL news for month 2025-05
# 2025-06-20 18:33:33,038 - INFO - Found 129 articles for AAPL in month 2025-05
# 2025-06-20 18:33:33,244 - INFO - Progress: 1184/1220 - Fetching AMZN news for month 2025-05
# 2025-06-20 18:33:35,004 - INFO - Found 147 articles for AMZN in month 2025-05
# 2025-06-20 18:33:35,211 - INFO - Progress: 1185/1220 - Fetching GOOG news for month 2025-05
# 2025-06-20 18:33:37,211 - INFO - Found 142 articles for GOOG in month 2025-05
# 2025-06-20 18:33:37,413 - INFO - Progress: 1186/1220 - Fetching META news for month 2025-05
# 2025-06-20 18:33:38,622 - INFO - Found 75 articles for META in month 2025-05
# 2025-06-20 18:33:38,828 - INFO - Progress: 1187/1220 - Fetching AVGO news for month 2025-05
# 2025-06-20 18:33:39,875 - INFO - Found 30 articles for AVGO in month 2025-05
# 2025-06-20 18:33:40,077 - INFO - Progress: 1188/1220 - Fetching BRK.B news for month 2025-05
# 2025-06-20 18:33:41,326 - INFO - Found 70 articles for BRK.B in month 2025-05
# 2025-06-20 18:33:41,531 - INFO - Progress: 1189/1220 - Fetching TSLA news for month 2025-05
# 2025-06-20 18:33:42,775 - INFO - Found 78 articles for TSLA in month 2025-05
# 2025-06-20 18:33:42,980 - INFO - Progress: 1190/1220 - Fetching JPM news for month 2025-05
# 2025-06-20 18:33:44,021 - INFO - Found 31 articles for JPM in month 2025-05
# 2025-06-20 18:33:44,223 - INFO - Progress: 1191/1220 - Fetching WMT news for month 2025-05
# 2025-06-20 18:33:45,305 - INFO - Found 47 articles for WMT in month 2025-05
# 2025-06-20 18:33:45,506 - INFO - Progress: 1192/1220 - Fetching LLY news for month 2025-05
# 2025-06-20 18:33:46,507 - INFO - Found 29 articles for LLY in month 2025-05
# 2025-06-20 18:33:46,710 - INFO - Progress: 1193/1220 - Fetching V news for month 2025-05
# 2025-06-20 18:33:47,673 - INFO - Found 15 articles for V in month 2025-05
# 2025-06-20 18:33:47,892 - INFO - Progress: 1194/1220 - Fetching ORCL news for month 2025-05
# 2025-06-20 18:33:48,879 - INFO - Found 17 articles for ORCL in month 2025-05
# 2025-06-20 18:33:49,088 - INFO - Progress: 1195/1220 - Fetching NFLX news for month 2025-05
# 2025-06-20 18:33:50,057 - INFO - Found 26 articles for NFLX in month 2025-05
# 2025-06-20 18:33:50,271 - INFO - Progress: 1196/1220 - Fetching MA news for month 2025-05
# 2025-06-20 18:33:51,037 - INFO - Found 5 articles for MA in month 2025-05
# 2025-06-20 18:33:51,253 - INFO - Progress: 1197/1220 - Fetching XOM news for month 2025-05
# 2025-06-20 18:33:52,264 - INFO - Found 19 articles for XOM in month 2025-05
# 2025-06-20 18:33:52,471 - INFO - Progress: 1198/1220 - Fetching COST news for month 2025-05
# 2025-06-20 18:33:53,488 - INFO - Found 18 articles for COST in month 2025-05
# 2025-06-20 18:33:53,696 - INFO - Progress: 1199/1220 - Fetching PG news for month 2025-05
# 2025-06-20 18:33:54,460 - INFO - Found 6 articles for PG in month 2025-05
# 2025-06-20 18:33:54,666 - INFO - Progress: 1200/1220 - Fetching JNJ news for month 2025-05
# 2025-06-20 18:33:55,685 - INFO - Found 15 articles for JNJ in month 2025-05
# 2025-06-20 18:33:55,895 - INFO - Progress: 1201/1220 - Fetching MSFT news for month 2025-06
# 2025-06-20 18:33:56,880 - INFO - Found 64 articles for MSFT in month 2025-06
# 2025-06-20 18:33:57,081 - INFO - Progress: 1202/1220 - Fetching NVDA news for month 2025-06
# 2025-06-20 18:33:58,376 - INFO - Found 117 articles for NVDA in month 2025-06
# 2025-06-20 18:33:58,590 - INFO - Progress: 1203/1220 - Fetching AAPL news for month 2025-06
# 2025-06-20 18:33:59,624 - INFO - Found 55 articles for AAPL in month 2025-06
# 2025-06-20 18:33:59,829 - INFO - Progress: 1204/1220 - Fetching AMZN news for month 2025-06
# 2025-06-20 18:34:01,110 - INFO - Found 94 articles for AMZN in month 2025-06
# 2025-06-20 18:34:01,321 - INFO - Progress: 1205/1220 - Fetching GOOG news for month 2025-06
# 2025-06-20 18:34:02,409 - INFO - Found 62 articles for GOOG in month 2025-06
# 2025-06-20 18:34:02,615 - INFO - Progress: 1206/1220 - Fetching META news for month 2025-06
# 2025-06-20 18:34:03,608 - INFO - Found 42 articles for META in month 2025-06
# 2025-06-20 18:34:03,820 - INFO - Progress: 1207/1220 - Fetching AVGO news for month 2025-06
# 2025-06-20 18:34:04,857 - INFO - Found 22 articles for AVGO in month 2025-06
# 2025-06-20 18:34:05,065 - INFO - Progress: 1208/1220 - Fetching BRK.B news for month 2025-06
# 2025-06-20 18:34:06,040 - INFO - Found 24 articles for BRK.B in month 2025-06
# 2025-06-20 18:34:06,254 - INFO - Progress: 1209/1220 - Fetching TSLA news for month 2025-06
# 2025-06-20 18:34:07,191 - INFO - Found 46 articles for TSLA in month 2025-06
# 2025-06-20 18:34:07,401 - INFO - Progress: 1210/1220 - Fetching JPM news for month 2025-06
# 2025-06-20 18:34:08,203 - INFO - Found 12 articles for JPM in month 2025-06
# 2025-06-20 18:34:08,413 - INFO - Progress: 1211/1220 - Fetching WMT news for month 2025-06
# 2025-06-20 18:34:09,204 - INFO - Found 14 articles for WMT in month 2025-06
# 2025-06-20 18:34:09,411 - INFO - Progress: 1212/1220 - Fetching LLY news for month 2025-06
# 2025-06-20 18:34:10,174 - INFO - Found 13 articles for LLY in month 2025-06
# 2025-06-20 18:34:10,378 - INFO - Progress: 1213/1220 - Fetching V news for month 2025-06
# 2025-06-20 18:34:11,163 - INFO - Found 12 articles for V in month 2025-06
# 2025-06-20 18:34:11,366 - INFO - Progress: 1214/1220 - Fetching ORCL news for month 2025-06
# 2025-06-20 18:34:12,378 - INFO - Found 20 articles for ORCL in month 2025-06
# 2025-06-20 18:34:12,585 - INFO - Progress: 1215/1220 - Fetching NFLX news for month 2025-06
# 2025-06-20 18:34:13,338 - INFO - Found 13 articles for NFLX in month 2025-06
# 2025-06-20 18:34:13,551 - INFO - Progress: 1216/1220 - Fetching MA news for month 2025-06
# 2025-06-20 18:34:14,356 - INFO - Found 4 articles for MA in month 2025-06
# 2025-06-20 18:34:14,566 - INFO - Progress: 1217/1220 - Fetching XOM news for month 2025-06
# 2025-06-20 18:34:15,319 - INFO - Found 8 articles for XOM in month 2025-06
# 2025-06-20 18:34:15,521 - INFO - Progress: 1218/1220 - Fetching COST news for month 2025-06
# 2025-06-20 18:34:16,274 - INFO - Found 14 articles for COST in month 2025-06
# 2025-06-20 18:34:16,487 - INFO - Progress: 1219/1220 - Fetching PG news for month 2025-06
# 2025-06-20 18:34:17,211 - INFO - Found 0 articles for PG in month 2025-06
# 2025-06-20 18:34:17,414 - INFO - Progress: 1220/1220 - Fetching JNJ news for month 2025-06
# 2025-06-20 18:34:18,198 - INFO - Found 6 articles for JNJ in month 2025-06
# 2025-06-20 18:34:19,992 - INFO - Data collection completed! Total articles: 163777
# 2025-06-20 18:34:19,992 - INFO - Data sorted by ticker, then by date and saved to: historical_news_monthly_final.csv
# Collection completed!
# Total articles collected: 163777
# Data saved to: historical_news_monthly_final.csv

# %%
# ANALYZE COLLECTED MONTHLY DATA
# Run this cell to get statistics about your collected data

def analyze_collected_data(filename: str = "historical_news_monthly_final.csv"):
    """
    Analyze the collected news data and show statistics.
    """
    try:
        if not os.path.exists(filename):
            print(f"File {filename} not found! Run the collection cell first.")
            return
        
        df = pd.read_csv(filename)
        
        print("DATA ANALYSIS REPORT")
        print("=" * 50)
        print(f"Total articles collected: {len(df):,}")
        print(f"Number of unique stocks: {df['ticker'].nunique()}")
        print(f"Date range: {df['date'].min()} to {df['date'].max()}")
        
        print("\nArticles by Stock:")
        stock_counts = df['ticker'].value_counts().sort_index()
        for ticker, count in stock_counts.items():
            print(f"   {ticker}: {count:,} articles")
        
        print("\nArticles by Month (based on collection start date):")
        df['month'] = pd.to_datetime(df['date']).dt.to_period('M')
        monthly_counts = df['month'].value_counts().sort_index()
        for month, count in monthly_counts.items():
            print(f"   {month}: {count:,} articles")
        
        print("\nTop 10 Publishers:")
        publisher_counts = df['publisher_name'].value_counts().head(10)
        for publisher, count in publisher_counts.items():
            print(f"   {publisher}: {count:,} articles")
        
        print("\nFile Information:")
        file_size = os.path.getsize(filename) / (1024 * 1024)  # in MB
        print(f"   File size: {file_size:.2f} MB")
        print(f"   Columns: {list(df.columns)}")
        
    except Exception as e:
        print(f"An error occurred during analysis: {e}")

# Run the analysis on the final output file
analyze_collected_data()
# Out:
# DATA ANALYSIS REPORT
# ==================================================
# Total articles collected: 163,777
# Number of unique stocks: 20
# Date range: 1/1/2022 to 9/9/2024
#
# Articles by Stock:
#    AAPL: 19,710 articles
#    AMZN: 21,218 articles
#    AVGO: 3,048 articles
#    BRK.B: 5,191 articles
#    COST: 3,635 articles
#    GOOG: 10,708 articles
#    JNJ: 4,216 articles
#    JPM: 5,166 articles
#    LLY: 2,885 articles
#    MA: 2,394 articles
#    META: 8,034 articles
#    MSFT: 15,744 articles
#    NFLX: 7,273 articles
#    NVDA: 17,700 articles
#    ORCL: 2,242 articles
#    PG: 1,929 articles
#    TSLA: 19,956 articles
#    V: 3,320 articles
#    WMT: 5,266 articles
#    XOM: 4,142 articles
#
# Articles by Month (based on collection start date):
#    2020-06: 19 articles
#    2020-07: 45 articles
#    2020-08: 50 articles
#    2020-09: 51 articles
#    2020-10: 55 articles
#    2020-11: 26 articles
#    2020-12: 14 articles
#    2021-01: 36 articles
#    2021-02: 31 articles
#    2021-03: 46 articles
#    2021-04: 1,173 articles
#    2021-05: 3,259 articles
#    2021-06: 3,445 articles
#    2021-07: 3,924 articles
#    2021-08: 3,360 articles
#    2021-09: 3,553 articles
#    2021-10: 4,252 articles
#    2021-11: 3,375 articles
#    2021-12: 3,527 articles
#    2022-01: 4,398 articles
#    2022-02: 3,322 articles
#    2022-03: 3,926 articles
#    2022-04: 4,271 articles
#    2022-05: 3,644 articles
#    2022-06: 3,457 articles
#    2022-07: 3,932 articles
#    2022-08: 3,609 articles
#    2022-09: 3,415 articles
#    2022-10: 4,128 articles
#    2022-11: 3,322 articles
#    2022-12: 3,611 articles
#    2023-01: 4,412 articles
#    2023-02: 3,282 articles
#    2023-03: 3,556 articles
#    2023-04: 3,996 articles
#    2023-05: 4,017 articles
#    2023-06: 3,836 articles
#    2023-07: 4,260 articles
#    2023-08: 3,841 articles
#    2023-09: 3,679 articles
#    2023-10: 4,349 articles
#    2023-11: 3,610 articles
#    2023-12: 3,726 articles
#    2024-01: 4,428 articles
#    2024-02: 4,386 articles
#    2024-03: 4,472 articles
#    2024-04: 3,938 articles
#    2024-05: 3,376 articles
#    2024-06: 3,264 articles
#    2024-07: 3,709 articles
#    2024-08: 1,334 articles
#    2024-09: 1,464 articles
#    2024-10: 1,422 articles
#    2024-11: 1,293 articles
#    2024-12: 1,264 articles
#    2025-01: 1,679 articles
#    2025-02: 1,383 articles
#    2025-03: 1,238 articles
#    2025-04: 1,394 articles
#    2025-05: 1,251 articles
#    2025-06: 642 articles
#
# Top 10 Publishers:
#    The Motley Fool: 60,668 articles
#    Zacks Investment Research: 36,041 articles
#    Benzinga: 26,801 articles
#    MarketWatch: 20,145 articles
#    Seeking Alpha: 9,571 articles
#    Investing.com: 7,210 articles
#    GlobeNewswire Inc.: 2,344 articles
#    Invezz: 490 articles
#    Quartz: 419 articles
#    PennyStocks: 88 articles
#
# File Information:
#    File size: 92.21 MB
#    Columns: ['ticker', 'date', 'title', 'description', 'author', 'published_utc', 'article_url', 'publisher_name', 'publisher_homepage_url', 'tickers', 'keywords', 'month']
